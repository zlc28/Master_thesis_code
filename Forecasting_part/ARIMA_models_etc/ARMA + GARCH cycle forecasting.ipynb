# %%
import pandas as pd
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.tsa.arima.model
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import itertools 
import statsmodels.graphics.tsaplots as sgt
from arch import arch_model

# %%
df = pd.read_csv('/windows/proga/global_mfdexport_1month_18072010_18072023.txt',sep=';')\
    .rename(columns={'<DATE>':'DATE','<OPEN>':'OPEN','<LOW>':'LOW','<CLOSE>':'CLOSE','<VOL>':'VOL','<HIGH>':'HIGH','<TICKER>':'TICKER'})\
    .drop(['<PER>','<TIME>','<OPENINT>'],1)
df.DATE = pd.to_datetime(df.DATE,format="%Y%m%d")
companies = df['TICKER'].unique()

# %% [markdown]
# # МОДЕЛЬ , РАБОТАЮЩАЯ ЦИКЛОМ С НЕИЗМЕННЫМИ ПАРАМЕТРАМИ

# %%
company_df = df.loc[df['TICKER'] == 'ЛУКОЙЛ']

company_df['earn'] = company_df.CLOSE.pct_change()

series = company_df[['DATE','earn']].set_index('DATE')

# %%
#Делаем train и test выборки
historic = series.earn.iloc[:int(len(series) * 0.7)].to_list()
test = series.earn.iloc[int(len(series) * 0.7):]

# %%
res = statsmodels.tsa.stattools.arma_order_select_ic(historic, ic=["aic", "bic"])
print(res.bic_min_order)
print(res.aic_min_order)
# Out:
# (0, 0)
# (3, 1)

# %%
upper_conf_int = []
lower_conf_int = []
predictions = []
for i in range(len(test)):
    model = ARIMA(historic, order=(res.aic_min_order[0] , 0 , res.aic_min_order[1]) )
    model_results = model.fit()
    arma_forecast = model_results.get_forecast(1)
    arma_predictions_df = arma_forecast.conf_int(alpha = 0.05)
    pred = model_results.predict(start=len(historic), end=len(historic), dynamic=False)
    predictions.append(pred[0])
    upper_conf_int.append(arma_predictions_df[0][1])
    lower_conf_int.append(arma_predictions_df[0][0])
    historic.append(test[i])
predictions = pd.DataFrame(predictions).set_index(test.index)
upper_conf_int = pd.DataFrame(upper_conf_int).set_index(test.index)   
lower_conf_int = pd.DataFrame(lower_conf_int).set_index(test.index)

# %%
plt.rcParams["figure.figsize"] = 18, 5

plt.plot(test, color = "blue", label = "Тестовая выборка")

plt.plot(predictions, color = "red", label = "Прогноз")
plt.plot(upper_conf_int, color = "green", linestyle = "--", label = "Conidence Levels(95%)")
plt.plot(lower_conf_int, color = "green", linestyle = "--")

# %% [markdown]
# ### ОЦЕНКА КАЧЕСТВА МОДЕЛИ

# %%
#Рассёт качества модели : MSE, MAE, Hit-Rate  

#MSE среднеквардратическая ошибка
test_score = mean_squared_error(test, predictions)
#MAE средняяабсолютная ошибка
mae = round(abs(test.values - predictions.values).mean(),10)
#Hit-Rate доля угаданных направлений
price_pred = pd.concat([test, predictions], axis=1)
price_pred.dropna(inplace=True)
price_pred.columns = ['Price', 'preds']
price_pred['hit'] = np.where(np.sign(price_pred['Price']) == np.sign(price_pred['preds']), 1, 0)
#Результирующее сообщение

print('MSE: %.5f' % test_score)
print(f'MAE is {mae}')
print(f"Hit rate: {round((price_pred['hit'].sum() / price_pred['hit'].count()) * 100,2)}%")
# Out:
# MSE: 0.01107
# MAE is 0.0829844055
# Hit rate: 58.33%

# %% [markdown]
# # МОДЕЛЬ , РАБОТАЮЩАЯ ЦИКЛОМ С ИЗМЕНЯЮЩИМЕСЯ ПАРАМЕТРАМИ

# %%
company_df = df.loc[df['TICKER'] == 'ФосАгро ао']
#company_df['earn'] = (company_df.CLOSE-company_df.CLOSE.shift(1).fillna(0))/company_df.CLOSE.shift(1).fillna(0)
company_df['earn'] = company_df.CLOSE.pct_change()
#company_df.replace([np.inf, -np.inf], 100, inplace=True)
#company_df = company_df.loc[company_df.earn != 100]
series = company_df[['DATE','earn']].set_index('DATE')

# %%
#Делаем train и test выборки
historic = series.earn.iloc[:int(len(series) * 0.7)].to_list()
test = series.earn.iloc[int(len(series) * 0.7):]

# %%
upper_conf_int = []
lower_conf_int = []
predictions = []
for i in range(len(test)):
    res = statsmodels.tsa.stattools.arma_order_select_ic(historic, ic=["aic", "bic"])
    model = ARIMA(historic, order=(res.aic_min_order[0] , 0 , res.aic_min_order[1]) )
    model_results = model.fit()
    arma_forecast = model_results.get_forecast(1)
    arma_predictions_df = arma_forecast.conf_int(alpha = 0.05)
    pred = model_results.predict(start=len(historic), end=len(historic), dynamic=False)
    predictions.append(pred[0])
    upper_conf_int.append(arma_predictions_df[0][1])
    lower_conf_int.append(arma_predictions_df[0][0])
    historic.append(test[i])
predictions = pd.DataFrame(predictions).set_index(test.index)
upper_conf_int = pd.DataFrame(upper_conf_int).set_index(test.index)   
lower_conf_int = pd.DataFrame(lower_conf_int).set_index(test.index)

# %%
plt.rcParams["figure.figsize"] = 18, 5

plt.plot(test, color = "blue", label = "Тестовая выборка")

plt.plot(predictions, color = "red", label = "Прогноз")
plt.plot(upper_conf_int, color = "green", linestyle = "--", label = "Conidence Levels(95%)")
plt.plot(lower_conf_int, color = "green", linestyle = "--")

# %% [markdown]
# ### ОЦЕНКА КАЧЕСТВА МОДЕЛИ

# %%
#Рассёт качества модели : MSE, MAE, Hit-Rate  

#MSE среднеквардратическая ошибка
test_score = mean_squared_error(test, predictions)
#MAE средняяабсолютная ошибка
mae = round(abs(test.values - predictions.values).mean(),10)
#Hit-Rate доля угаданных направлений
price_pred = pd.concat([test, predictions], axis=1)
price_pred.dropna(inplace=True)
price_pred.columns = ['Price', 'preds']
price_pred['hit'] = np.where(np.sign(price_pred['Price']) == np.sign(price_pred['preds']), 1, 0)
#Результирующее сообщение

print('MSE: %.5f' % test_score)
print(f'MAE is {mae}')
print(f"Hit rate: {round((price_pred['hit'].sum() / price_pred['hit'].count()) * 100,2)}%")
# Out:
# MSE: 0.01267
# MAE is 0.0640884397
# Hit rate: 70.45%

# %% [markdown]
# # ОБЩАЯ ПРОВЕРКА ВСЕХ КОМПАНИЙ НА ЦИКЛИЧЕСКОЕ ПРОГНОЗИРОВАНИЕ С МЕНЯЮЩИМЕСЯ ПАРАМЕТРАМИ

# %%
for j in companies:
    #Создаём дф и временной ряд доходностей
    company_df = df.loc[df['TICKER'] == j]
    company_df['earn'] = company_df.CLOSE.pct_change()
    series = company_df[['DATE','earn']].set_index('DATE')
#==============================Проверяем модель на параметрах BIC============================
    #Делаем train и test выборки
    historic = series.earn.iloc[:int(len(series) * 0.7)].to_list()
    test = series.earn.iloc[int(len(series) * 0.7):]

    upper_conf_int = []
    lower_conf_int = []
    predictions = []
    for i in range(len(test)):
        res = statsmodels.tsa.stattools.arma_order_select_ic(historic, ic=["aic", "bic"])
        model = ARIMA(historic, order=(res.bic_min_order[0] , 0 , res.bic_min_order[1]) )
        model_results = model.fit()
        arma_forecast = model_results.get_forecast(1)
        arma_predictions_df = arma_forecast.conf_int(alpha = 0.05)
        pred = model_results.predict(start=len(historic), end=len(historic), dynamic=False)
        predictions.append(pred[0])
        upper_conf_int.append(arma_predictions_df[0][1])
        lower_conf_int.append(arma_predictions_df[0][0])
        historic.append(test[i])
    predictions = pd.DataFrame(predictions).set_index(test.index)
    upper_conf_int = pd.DataFrame(upper_conf_int).set_index(test.index)   
    lower_conf_int = pd.DataFrame(lower_conf_int).set_index(test.index)          
    
    
    #Рассёт качества модели : MSE, MAE, Hit-Rate  

    #MSE среднеквардратическая ошибка
    test_score = mean_squared_error(test, predictions)
    #MAE средняяабсолютная ошибка
    mae = round(abs(test.values - predictions.values).mean(),10)
    #Hit-Rate доля угаданных направлений
    price_pred = pd.concat([test, predictions], axis=1)
    price_pred.dropna(inplace=True)
    price_pred.columns = ['Price', 'preds']
    price_pred['hit'] = np.where(np.sign(price_pred['Price']) == np.sign(price_pred['preds']), 1, 0)
    #Результирующее сообщение
    print("Актив {} , Параметры BIC".format(j))
    print('MSE: %.5f' % test_score)
    print(f'MAE is {mae}')
    print(f"Hit rate: {round((price_pred['hit'].sum() / price_pred['hit'].count()) * 100,2)}%\n")
    
    
#==============================Проверяем модель на параметрах AIC============================
    #Делаем train и test выборки
    historic = series.earn.iloc[:int(len(series) * 0.7)].to_list()
    test = series.earn.iloc[int(len(series) * 0.7):]

    upper_conf_int = []
    lower_conf_int = []
    predictions = []
    for i in range(len(test)):
        res = statsmodels.tsa.stattools.arma_order_select_ic(historic, ic=["aic", "bic"])
        model = ARIMA(historic, order=(res.aic_min_order[0] , 0 , res.aic_min_order[1]) )
        model_results = model.fit()
        arma_forecast = model_results.get_forecast(1)
        arma_predictions_df = arma_forecast.conf_int(alpha = 0.05)
        pred = model_results.predict(start=len(historic), end=len(historic), dynamic=False)
        predictions.append(pred[0])
        upper_conf_int.append(arma_predictions_df[0][1])
        lower_conf_int.append(arma_predictions_df[0][0])
        historic.append(test[i])
    predictions = pd.DataFrame(predictions).set_index(test.index)
    upper_conf_int = pd.DataFrame(upper_conf_int).set_index(test.index)   
    lower_conf_int = pd.DataFrame(lower_conf_int).set_index(test.index)          
    
    
    #Рассёт качества модели : MSE, MAE, Hit-Rate  

    #MSE среднеквардратическая ошибка
    test_score = mean_squared_error(test, predictions)
    #MAE средняяабсолютная ошибка
    mae = round(abs(test.values - predictions.values).mean(),10)
    #Hit-Rate доля угаданных направлений
    price_pred = pd.concat([test, predictions], axis=1)
    price_pred.dropna(inplace=True)
    price_pred.columns = ['Price', 'preds']
    price_pred['hit'] = np.where(np.sign(price_pred['Price']) == np.sign(price_pred['preds']), 1, 0)
    #Результирующее сообщение
    print("Актив {} , Параметры AIC".format(j))
    print('MSE: %.5f' % test_score)
    print(f'MAE is {mae}')
    print(f"Hit rate: {round((price_pred['hit'].sum() / price_pred['hit'].count()) * 100,2)}%\n")
    print('============')
# Out:
# Актив ГАЗПРОМ ао , Параметры BIC
# MSE: 0.01348
# MAE is 0.0825966856
# Hit rate: 43.75%
#
# Актив ГАЗПРОМ ао , Параметры AIC
# MSE: 0.01365
# MAE is 0.084892854
# Hit rate: 47.92%
#
# ============
# Актив Сбербанк , Параметры BIC
# MSE: 0.01386
# MAE is 0.0762967129
# Hit rate: 64.58%
#
# Актив Сбербанк , Параметры AIC
# MSE: 0.01404
# MAE is 0.078170265
# Hit rate: 62.5%
#
# ============
# Актив ЛУКОЙЛ , Параметры BIC
# MSE: 0.01047
# MAE is 0.078830152
# Hit rate: 60.42%
#
# Актив ЛУКОЙЛ , Параметры AIC
# MSE: 0.01124
# MAE is 0.0823680719
# Hit rate: 52.08%
#
# ============
# Актив ГМКНорНик , Параметры BIC
# MSE: 0.00597
# MAE is 0.0605331677
# Hit rate: 56.25%
#
# Актив ГМКНорНик , Параметры AIC
# MSE: 0.00581
# MAE is 0.0611318435
# Hit rate: 58.33%
#
# ============
# Актив Магнит ао , Параметры BIC
# MSE: 0.01221
# MAE is 0.0841032849
# Hit rate: 60.42%
#
# Актив Магнит ао , Параметры AIC
# MSE: 0.01298
# MAE is 0.0865139763
# Hit rate: 56.25%
#
# ============
# Актив Татнфт 3ао , Параметры BIC
# MSE: 0.01066
# MAE is 0.0791147585
# Hit rate: 43.75%
#
# Актив Татнфт 3ао , Параметры AIC
# MSE: 0.01075
# MAE is 0.0809581287
# Hit rate: 45.83%
#
# ============
# Актив Новатэк ао , Параметры BIC
# MSE: 0.01327
# MAE is 0.0851933885
# Hit rate: 60.42%
#
# Актив Новатэк ао , Параметры AIC
# MSE: 0.01280
# MAE is 0.0885291146
# Hit rate: 52.08%
#
# ============
# Актив Сургнфгз , Параметры BIC
# MSE: 0.01485
# MAE is 0.0871068656
# Hit rate: 45.83%
#
# Актив Сургнфгз , Параметры AIC
# MSE: 0.01416
# MAE is 0.0885245941
# Hit rate: 58.33%
#
# ============
# Актив Полюс , Параметры BIC
# MSE: 0.02173
# MAE is 0.1175688124
# Hit rate: 48.15%
#
# Актив Полюс , Параметры AIC
# MSE: 0.01989
# MAE is 0.1177788946
# Hit rate: 51.85%
#
# ============
# Актив Сургнфгз-п , Параметры BIC
# MSE: 0.00989
# MAE is 0.0795504179
# Hit rate: 54.17%
#
# Актив Сургнфгз-п , Параметры AIC
# MSE: 0.01086
# MAE is 0.0822780324
# Hit rate: 52.08%
#
# ============
# Актив ПИК ао , Параметры BIC
# MSE: 0.01686
# MAE is 0.0863223321
# Hit rate: 60.42%
#
# Актив ПИК ао , Параметры AIC
# MSE: 0.01780
# MAE is 0.0922288617
# Hit rate: 64.58%
#
# ============
# Актив Роснефть , Параметры BIC
# MSE: 0.01859
# MAE is 0.0934581488
# Hit rate: 45.83%
#
# Актив Роснефть , Параметры AIC
# MSE: 0.01974
# MAE is 0.0982796187
# Hit rate: 47.92%
#
# ============
# Актив Сбербанк-п , Параметры BIC
# MSE: 0.01291
# MAE is 0.0749328286
# Hit rate: 66.67%
#
# Актив Сбербанк-п , Параметры AIC
# MSE: 0.01339
# MAE is 0.0766379153
# Hit rate: 60.42%
#
# ============
# Актив СевСт-ао , Параметры BIC
# MSE: 0.00935
# MAE is 0.0777633546
# Hit rate: 54.17%
#
# Актив СевСт-ао , Параметры AIC
# MSE: 0.00998
# MAE is 0.0800870582
# Hit rate: 47.92%
#
# ============
# Актив НЛМК ао , Параметры BIC
# MSE: 0.00845
# MAE is 0.0716551794
# Hit rate: 54.17%
#
# Актив НЛМК ао , Параметры AIC
# MSE: 0.00873
# MAE is 0.0718119002
# Hit rate: 56.25%
#
# ============
# Актив ИнтерРАОао , Параметры BIC
# MSE: 0.61157
# MAE is 0.7720035008
# Hit rate: 50.0%
#
# Актив ИнтерРАОао , Параметры AIC
# MSE: 0.61157
# MAE is 0.7720035008
# Hit rate: 50.0%
#
# ============
# Актив Yandex clA , Параметры BIC
# MSE: 0.01862
# MAE is 0.0974304799
# Hit rate: 57.58%
#
# Актив Yandex clA , Параметры AIC
# MSE: 0.01961
# MAE is 0.0980868156
# Hit rate: 54.55%
#
# ============
# Актив АЛРОСА ао , Параметры BIC
# MSE: 0.01120
# MAE is 0.0838545045
# Hit rate: 44.19%
#
# Актив АЛРОСА ао , Параметры AIC
# MSE: 0.01206
# MAE is 0.0847368315
# Hit rate: 48.84%
#
# ============
# Актив РУСАЛ ао , Параметры BIC
# MSE: 0.01237
# MAE is 0.0652244775
# Hit rate: 72.73%
#
# Актив РУСАЛ ао , Параметры AIC
# MSE: 0.01237
# MAE is 0.0652244775
# Hit rate: 72.73%
#
# ============
# Актив МТС-ао , Параметры BIC
# MSE: 0.00753
# MAE is 0.0608945578
# Hit rate: 52.08%
#
# Актив МТС-ао , Параметры AIC
# MSE: 0.00663
# MAE is 0.0652283683
# Hit rate: 54.17%
#
# ============
# Актив ММК , Параметры BIC
# MSE: 0.01239
# MAE is 0.0886861669
# Hit rate: 54.17%
#
# Актив ММК , Параметры AIC
# MSE: 0.01347
# MAE is 0.0893207263
# Hit rate: 50.0%
#
# ============
# Актив ФосАгро ао , Параметры BIC
# MSE: 0.01267
# MAE is 0.0640884397
# Hit rate: 70.45%
#
# Актив ФосАгро ао , Параметры AIC
# MSE: 0.01267
# MAE is 0.0640884397
# Hit rate: 70.45%
#
# ============
# Актив Ростел -ао , Параметры BIC
# MSE: 0.00450
# MAE is 0.0515649783
# Hit rate: 41.67%
#
# Актив Ростел -ао , Параметры AIC
# MSE: 0.00506
# MAE is 0.0536729659
# Hit rate: 45.83%
#
# ============
# Актив ВТБ ао , Параметры BIC
# MSE: 0.01426
# MAE is 0.0761128348
# Hit rate: 43.75%
#
# Актив ВТБ ао , Параметры AIC
# MSE: 0.01505
# MAE is 0.0793992572
# Hit rate: 47.92%
#
# ============
# Актив Татнфт 3ап , Параметры BIC
# MSE: 0.00972
# MAE is 0.0735504398
# Hit rate: 50.0%
#
# Актив Татнфт 3ап , Параметры AIC
# MSE: 0.01025
# MAE is 0.0768096536
# Hit rate: 45.83%
#
# ============
# Актив TCS-гдр , Параметры BIC
# MSE: 0.01894
# MAE is 0.1039522542
# Hit rate: 57.14%
#
# Актив TCS-гдр , Параметры AIC
# MSE: 0.01894
# MAE is 0.1039522542
# Hit rate: 57.14%
#
# ============
# Актив AGRO-гдр , Параметры BIC
# MSE: 0.01166
# MAE is 0.081923003
# Hit rate: 65.62%
#
# Актив AGRO-гдр , Параметры AIC
# MSE: 0.01142
# MAE is 0.0831046499
# Hit rate: 62.5%
#
# ============
# Актив OZON-адр , Параметры BIC
# MSE: 0.01674
# MAE is 0.0916532092
# Hit rate: 50.0%
#
# Актив OZON-адр , Параметры AIC
# MSE: 0.01674
# MAE is 0.0916532092
# Hit rate: 50.0%
#
# ============
# Актив Аэрофлот , Параметры BIC
# MSE: 0.01283
# MAE is 0.0756922782
# Hit rate: 45.83%
#
# Актив Аэрофлот , Параметры AIC
# MSE: 0.01354
# MAE is 0.0794625266
# Hit rate: 50.0%
#
# ============
# Актив Система ао , Параметры BIC
# MSE: 0.01402
# MAE is 0.0881147784
# Hit rate: 60.42%
#
# Актив Система ао , Параметры AIC
# MSE: 0.01450
# MAE is 0.0890464923
# Hit rate: 45.83%
#
# ============
# Актив Россети , Параметры BIC
# MSE: 0.01588
# MAE is 0.1119167795
# Hit rate: 66.67%
#
# Актив Россети , Параметры AIC
# MSE: 0.01588
# MAE is 0.1119167795
# Hit rate: 66.67%
#
# ============
# Актив Транснф ап , Параметры BIC
# MSE: 0.00791
# MAE is 0.069010647
# Hit rate: 50.0%
#
# Актив Транснф ап , Параметры AIC
# MSE: 0.00791
# MAE is 0.069010647
# Hit rate: 50.0%
#
# ============
# Актив МКБ ао , Параметры BIC
# MSE: 0.00784
# MAE is 0.0648358858
# Hit rate: 40.0%
#
# Актив МКБ ао , Параметры AIC
# MSE: 0.00832
# MAE is 0.0669617231
# Hit rate: 36.67%
#
# ============
# Актив VK-гдр , Параметры BIC
# MSE: 0.01496
# MAE is 0.093451185
# Hit rate: 50.0%
#
# Актив VK-гдр , Параметры AIC
# MSE: 0.01496
# MAE is 0.093451185
# Hit rate: 50.0%
#
# ============
# Актив ЭН+ГРУП ао , Параметры BIC
# MSE: 0.02145
# MAE is 0.1226499786
# Hit rate: 69.23%
#
# Актив ЭН+ГРУП ао , Параметры AIC
# MSE: 0.01860
# MAE is 0.1241055477
# Hit rate: 69.23%
#
# ============
# Актив Сегежа , Параметры BIC
# MSE: 0.00619
# MAE is 0.0741269807
# Hit rate: 33.33%
#
# Актив Сегежа , Параметры AIC
# MSE: 0.00619
# MAE is 0.0741269807
# Hit rate: 33.33%
#
# ============
# Актив FIVE-гдр , Параметры BIC
# MSE: 0.03452
# MAE is 0.1339354891
# Hit rate: 35.0%
#
# Актив FIVE-гдр , Параметры AIC
# MSE: 0.03851
# MAE is 0.1424068716
# Hit rate: 50.0%
#
# ============
# Актив Polymetal , Параметры BIC
# MSE: 0.03394
# MAE is 0.1441150434
# Hit rate: 43.24%
#
# Актив Polymetal , Параметры AIC
# MSE: 0.03519
# MAE is 0.1446917137
# Hit rate: 45.95%
#
# ============
# Актив МосБиржа , Параметры BIC
# MSE: 0.00825
# MAE is 0.0628067783
# Hit rate: 55.26%
#
# Актив МосБиржа , Параметры AIC
# MSE: 0.00879
# MAE is 0.0675079536
# Hit rate: 50.0%
#
# ============
# Актив GLTR-гдр , Параметры BIC
# MSE: 0.02133
# MAE is 0.116855282
# Hit rate: 63.64%
#
# Актив GLTR-гдр , Параметры AIC
# MSE: 0.02571
# MAE is 0.128370923
# Hit rate: 54.55%
#
# ============
# Актив РусГидро , Параметры BIC
# MSE: 0.00424
# MAE is 0.0463807194
# Hit rate: 39.58%
#
# Актив РусГидро , Параметры AIC
# MSE: 0.00446
# MAE is 0.0466419624
# Hit rate: 35.42%
#
# ============
# Актив FIXP-гдр , Параметры BIC
# MSE: 0.01290
# MAE is 0.0910348905
# Hit rate: 44.44%
#
# Актив FIXP-гдр , Параметры AIC
# MSE: 0.01290
# MAE is 0.0910348905
# Hit rate: 44.44%
#
# ============
