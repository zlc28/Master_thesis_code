# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from itertools import product

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # ТОРГОВЫЙ АЛГОРИТМ

# %%
total_df = pd.read_csv('total_df.csv',index_col='df_index')\
    .rename(columns={'Price':'actual_return','pred':'predicted_return','lower':'lower_ci','upper':'upper_ci'})

# %%
total_df
# Out:
#             actual_return  lower_ci  predicted_return  upper_ci  \
# df_index
# 2019-08-01      -0.020051 -0.133287          0.005932  0.145150
# 2019-09-01      -0.026922 -0.132970          0.005693  0.144357
# 2019-10-01       0.150952 -0.132769          0.005397  0.143562
# 2019-11-01      -0.009462 -0.133450          0.006708  0.146866
# 2019-12-01      -0.004426 -0.132999          0.006564  0.146126
# ...                   ...       ...               ...       ...
# 2023-03-01      -0.022434 -0.320876         -0.034066  0.252743
# 2023-04-01       0.011474 -0.303213         -0.022398  0.258418
# 2023-05-01       0.032048 -0.306941         -0.031478  0.243985
# 2023-06-01       0.033251 -0.314194         -0.043003  0.228188
# 2023-07-01       0.075266 -0.313762         -0.046117  0.221528
#
#             prob_of_growth      ticker
# df_index
# 2019-08-01        0.533276  ГАЗПРОМ ао
# 2019-09-01        0.532069  ГАЗПРОМ ао
# 2019-10-01        0.530512  ГАЗПРОМ ао
# 2019-11-01        0.537368  ГАЗПРОМ ао
# 2019-12-01        0.536721  ГАЗПРОМ ао
# ...                    ...         ...
# 2023-03-01        0.407959    FIXP-гдр
# 2023-04-01        0.437888    FIXP-гдр
# 2023-05-01        0.411389    FIXP-гдр
# 2023-06-01        0.377978    FIXP-гдр
# 2023-07-01        0.367789    FIXP-гдр
#
# [1542 rows x 6 columns]

# %% [markdown]
# # ТОРГОВЫЙ АЛГОРИТМ

# %%
trading_days = total_df.index.unique() #Набор торговых дней с предсказаниями и фактами
bank = 1000 #Сумма денег на моём счету , которые я вкладываю . Это не накопленная стоимость портфеля 
portfolio = {} #Ключ - актив , значение - накопленный по нему доход
grow_hit = 0 #Подсчёт попаданий на росте
fall_hit = 0 #Подсчёт попаданий на падении
grow_miss = 0 #Подсчёт промахов и на росте и на падении
fall_miss = 0
grow_hit_list = [] 
fall_hit_list = [] 
grow_miss_list = [] 
fall_miss_list = []
fall_miss_ratio = []
capital = [] #Сумма денег в портфеле и банке которую в корце визуализирую

# %%
for day in trading_days:
    #Устанавливаем активы , которые вносим в списки потенциального роста и потенциального падения
    #good_assets = total_df.loc[day].query('prob_of_growth > 0.7').ticker.values
    #bad_assets = total_df.loc[day].query('prob_of_growth < 0.3').ticker.values
    good_assets = total_df.loc[(total_df.prob_of_growth > 0.8) & (total_df.index == day)].ticker.values
    bad_assets = total_df.loc[(total_df.prob_of_growth < 0.3) & (total_df.index == day)].ticker.values
    
    
    #Продаём все активы перед началом торгового дня
    for asset in list(portfolio):
        bank+=portfolio[asset]
        del portfolio[asset]

    #Продаём активы из зоны падения и возвращаем полученные деньги в банк
    for asset in bad_assets: 
        if asset in list(portfolio):
            bank+=portfolio[asset]
            del portfolio[asset]
        #Проверяем угадали ли направление
        if 1 > (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):#1+реальная доходность
            fall_hit+=1
        elif 1 < (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
            fall_miss+=1
    
    
    #Определяем разер вложений.
    invest_ammout = bank/len(good_assets)#вкладываем весь банк равномерно
    
    
    #Покупаем активы из зоны роста
    for asset in good_assets: 
        if asset not in list(portfolio): #Если его нет в портфеле ,то добавляем его
            portfolio[asset] = (invest_ammout)*(1 + total_df.loc[total_df.ticker == asset].loc[day][0])#(1+real_ret)
            bank -= invest_ammout
            #Проверка угадано ли направление доходности
            if 1 < (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
                grow_hit+=1
            elif 1 > (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
                grow_miss+=1
        #elif asset in list(portfolio): #Если такой актив уже есть
            #portfolio[asset] += invest_ammout #Прибавляем к уже имеющимся вложениям а затем умножем на 1+real return
            #portfolio[asset] = portfolio[asset] * (1 + total_df.loc[total_df.ticker == asset].loc[day][0])
            #bank -= invest_ammout
            #Проверка угадано ли направление доходности
            #if 1 < (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
                #grow_hit+=1
            #elif 1 > (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
                #miss+=1 
        
        print(f"В актив { asset } вложил { invest_ammout } и получил {(invest_ammout)*(1 + total_df.loc[total_df.ticker == asset].loc[day][0])}")    
        
#Пополняю списки попаданий и промахов в конце каждого дня
    grow_hit_list.append(grow_hit)
    fall_hit_list.append(fall_hit)
    grow_miss_list.append(grow_miss)
    fall_miss_list.append(fall_miss)
    fall_miss_ratio.append( (grow_hit+fall_hit)/(grow_miss+fall_miss) )
    capital.append( bank+(sum(portfolio[x] for x in portfolio)) )
#____________________ИНФОРМАЦИОННОЕ ОКНО_____________________   
    if len(list(portfolio)) == 0 :
        print(f"В день {day} ничего не покупалось")
    print(f"Банк {bank}")
    print(f"Портфель на момент {day} : {list(portfolio)}")
    print(f"Накопленная доходность портфеля : {sum(portfolio[x] for x in portfolio)}")
    print(f"Угаданных направлений: {grow_hit+fall_hit}")
    print(f"Неугаданных направлений: {fall_miss+grow_miss}")
    print('___________________________\n')
# Out:
# В актив Новатэк ао вложил 1000.0 и получил 976.0533494998484
# Банк 0.0
# Портфель на момент 2019-08-01 : ['Новатэк ао']
# Накопленная доходность портфеля : 976.0533494998484
# Угаданных направлений: 0
# Неугаданных направлений: 1
# ___________________________
#
# В день 2019-09-01 ничего не покупалось
# Банк 976.0533494998484
# Портфель на момент 2019-09-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 0
# Неугаданных направлений: 2
# ___________________________
#
# В день 2019-10-01 ничего не покупалось
# Банк 976.0533494998484
# Портфель на момент 2019-10-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 0
# Неугаданных направлений: 4
# ___________________________
#
# В день 2019-11-01 ничего не покупалось
# Банк 976.0533494998484
# Портфель на момент 2019-11-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 0
# Неугаданных направлений: 5
# ___________________________
#
# В день 2019-12-01 ничего не покупалось
# Банк 976.0533494998484
# Портфель на момент 2019-12-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 0
# Неугаданных направлений: 5
# ___________________________
#
# В день 2020-01-01 ничего не покупалось
# Банк 976.0533494998484
# Портфель на момент 2020-01-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 0
# Неугаданных направлений: 5
# ___________________________
#
# В актив ПИК ао вложил 976.0533494998484 и получил 875.8936049575086
# Банк 0.0
# Портфель на момент 2020-02-01 : ['ПИК ао']
# Накопленная доходность портфеля : 875.8936049575086
# Угаданных направлений: 1
# Неугаданных направлений: 6
# ___________________________
#
# В день 2020-03-01 ничего не покупалось
# Банк 875.8936049575086
# Портфель на момент 2020-03-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 1
# Неугаданных направлений: 6
# ___________________________
#
# В день 2020-04-01 ничего не покупалось
# Банк 875.8936049575086
# Портфель на момент 2020-04-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 3
# Неугаданных направлений: 6
# ___________________________
#
# В актив Роснефть вложил 437.9468024787543 и получил 490.85531682558434
# В актив Татнфт 3ап вложил 437.9468024787543 и получил 433.6022611586966
# Банк 0.0
# Портфель на момент 2020-05-01 : ['Роснефть', 'Татнфт 3ап']
# Накопленная доходность портфеля : 924.457577984281
# Угаданных направлений: 4
# Неугаданных направлений: 7
# ___________________________
#
# В актив ПИК ао вложил 924.457577984281 и получил 1023.4292019883289
# Банк 0.0
# Портфель на момент 2020-06-01 : ['ПИК ао']
# Накопленная доходность портфеля : 1023.4292019883289
# Угаданных направлений: 6
# Неугаданных направлений: 8
# ___________________________
#
# В день 2020-07-01 ничего не покупалось
# Банк 1023.4292019883289
# Портфель на момент 2020-07-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 6
# Неугаданных направлений: 8
# ___________________________
#
# В день 2020-08-01 ничего не покупалось
# Банк 1023.4292019883289
# Портфель на момент 2020-08-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 6
# Неугаданных направлений: 10
# ___________________________
#
# В день 2020-09-01 ничего не покупалось
# Банк 1023.4292019883289
# Портфель на момент 2020-09-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 6
# Неугаданных направлений: 10
# ___________________________
#
# В день 2020-10-01 ничего не покупалось
# Банк 1023.4292019883289
# Портфель на момент 2020-10-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 7
# Неугаданных направлений: 10
# ___________________________
#
# В день 2020-11-01 ничего не покупалось
# Банк 1023.4292019883289
# Портфель на момент 2020-11-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 7
# Неугаданных направлений: 10
# ___________________________
#
# В день 2020-12-01 ничего не покупалось
# Банк 1023.4292019883289
# Портфель на момент 2020-12-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 8
# Неугаданных направлений: 10
# ___________________________
#
# В день 2021-01-01 ничего не покупалось
# Банк 1023.4292019883289
# Портфель на момент 2021-01-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 9
# Неугаданных направлений: 12
# ___________________________
#
# В актив ЛУКОЙЛ вложил 1023.4292019883289 и получил 1061.2106222216714
# Банк 0.0
# Портфель на момент 2021-02-01 : ['ЛУКОЙЛ']
# Накопленная доходность портфеля : 1061.2106222216714
# Угаданных направлений: 10
# Неугаданных направлений: 12
# ___________________________
#
# В актив ПИК ао вложил 1061.2106222216714 и получил 1290.0289997686898
# Банк 0.0
# Портфель на момент 2021-03-01 : ['ПИК ао']
# Накопленная доходность портфеля : 1290.0289997686898
# Угаданных направлений: 11
# Неугаданных направлений: 13
# ___________________________
#
# В день 2021-04-01 ничего не покупалось
# Банк 1290.0289997686898
# Портфель на момент 2021-04-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 11
# Неугаданных направлений: 13
# ___________________________
#
# В день 2021-05-01 ничего не покупалось
# Банк 1290.0289997686898
# Портфель на момент 2021-05-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 11
# Неугаданных направлений: 16
# ___________________________
#
# В день 2021-06-01 ничего не покупалось
# Банк 1290.0289997686898
# Портфель на момент 2021-06-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 11
# Неугаданных направлений: 16
# ___________________________
#
# В день 2021-07-01 ничего не покупалось
# Банк 1290.0289997686898
# Портфель на момент 2021-07-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 12
# Неугаданных направлений: 17
# ___________________________
#
# В актив Сургнфгз-п вложил 1290.0289997686898 и получил 1310.0058267992283
# Банк 0.0
# Портфель на момент 2021-08-01 : ['Сургнфгз-п']
# Накопленная доходность портфеля : 1310.0058267992283
# Угаданных направлений: 13
# Неугаданных направлений: 17
# ___________________________
#
# В день 2021-09-01 ничего не покупалось
# Банк 1310.0058267992283
# Портфель на момент 2021-09-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 15
# Неугаданных направлений: 18
# ___________________________
#
# В день 2021-10-01 ничего не покупалось
# Банк 1310.0058267992283
# Портфель на момент 2021-10-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 15
# Неугаданных направлений: 18
# ___________________________
#
# В день 2021-11-01 ничего не покупалось
# Банк 1310.0058267992283
# Портфель на момент 2021-11-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 15
# Неугаданных направлений: 18
# ___________________________
#
# В день 2021-12-01 ничего не покупалось
# Банк 1310.0058267992283
# Портфель на момент 2021-12-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 15
# Неугаданных направлений: 19
# ___________________________
#
# В день 2022-01-01 ничего не покупалось
# Банк 1310.0058267992283
# Портфель на момент 2022-01-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 17
# Неугаданных направлений: 19
# ___________________________
#
# В день 2022-02-01 ничего не покупалось
# Банк 1310.0058267992283
# Портфель на момент 2022-02-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 17
# Неугаданных направлений: 19
# ___________________________
#
# В актив МТС-ао вложил 436.6686089330761 и получил 479.13086676725794
# В актив МКБ ао вложил 436.6686089330761 и получил 487.17689290637963
# В актив МосБиржа вложил 436.6686089330761 и получил 454.91075896598335
# Банк 1.1368683772161603e-13
# Портфель на момент 2022-03-01 : ['МТС-ао', 'МКБ ао', 'МосБиржа']
# Накопленная доходность портфеля : 1421.218518639621
# Угаданных направлений: 20
# Неугаданных направлений: 23
# ___________________________
#
# В актив ЛУКОЙЛ вложил 284.24370372792424 и получил 235.17663480094717
# В актив Татнфт 3ао вложил 284.24370372792424 и получил 266.5733812037988
# В актив Полюс вложил 284.24370372792424 и получил 304.41122666862634
# В актив МТС-ао вложил 284.24370372792424 и получил 248.98867070740653
# В актив Татнфт 3ап вложил 284.24370372792424 и получил 284.80213929516964
# Банк 1.1368683772161603e-13
# Портфель на момент 2022-04-01 : ['ЛУКОЙЛ', 'Татнфт 3ао', 'Полюс', 'МТС-ао', 'Татнфт 3ап']
# Накопленная доходность портфеля : 1339.9520526759484
# Угаданных направлений: 24
# Неугаданных направлений: 26
# ___________________________
#
# В актив FIVE-гдр вложил 1339.9520526759486 и получил 1104.7119522289627
# Банк 0.0
# Портфель на момент 2022-05-01 : ['FIVE-гдр']
# Накопленная доходность портфеля : 1104.7119522289627
# Угаданных направлений: 28
# Неугаданных направлений: 28
# ___________________________
#
# В актив Магнит ао вложил 368.2373174096542 и получил 336.33399809959366
# В актив Роснефть вложил 368.2373174096542 и получил 353.8301544606028
# В актив МТС-ао вложил 368.2373174096542 и получил 395.318900863002
# Банк 0.0
# Портфель на момент 2022-06-01 : ['Магнит ао', 'Роснефть', 'МТС-ао']
# Накопленная доходность портфеля : 1085.4830534231985
# Угаданных направлений: 30
# Неугаданных направлений: 30
# ___________________________
#
# В актив ПИК ао вложил 542.7415267115992 и получил 573.1457568752814
# В актив МКБ ао вложил 542.7415267115992 и получил 532.8378814477621
# Банк 0.0
# Портфель на момент 2022-07-01 : ['ПИК ао', 'МКБ ао']
# Накопленная доходность портфеля : 1105.9836383230436
# Угаданных направлений: 32
# Неугаданных направлений: 33
# ___________________________
#
# В актив Сургнфгз-п вложил 552.9918191615218 и получил 546.0205423952607
# В актив МТС-ао вложил 552.9918191615218 и получил 536.7507367749748
# Банк 0.0
# Портфель на момент 2022-08-01 : ['Сургнфгз-п', 'МТС-ао']
# Накопленная доходность портфеля : 1082.7712791702356
# Угаданных направлений: 32
# Неугаданных направлений: 36
# ___________________________
#
# В день 2022-09-01 ничего не покупалось
# Банк 1082.7712791702356
# Портфель на момент 2022-09-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 33
# Неугаданных направлений: 37
# ___________________________
#
# В актив Сургнфгз-п вложил 360.9237597234119 и получил 427.120458381774
# В актив МТС-ао вложил 360.9237597234119 и получил 425.23655072030476
# В актив ЭН+ГРУП ао вложил 360.9237597234119 и получил 437.659749693932
# Банк 0.0
# Портфель на момент 2022-10-01 : ['Сургнфгз-п', 'МТС-ао', 'ЭН+ГРУП ао']
# Накопленная доходность портфеля : 1290.016758796011
# Угаданных направлений: 36
# Неугаданных направлений: 39
# ___________________________
#
# В актив Полюс вложил 645.0083793980054 и получил 782.7673213514574
# В актив МТС-ао вложил 645.0083793980054 и получил 675.2877807337842
# Банк 0.0
# Портфель на момент 2022-11-01 : ['Полюс', 'МТС-ао']
# Накопленная доходность портфеля : 1458.0551020852417
# Угаданных направлений: 42
# Неугаданных направлений: 40
# ___________________________
#
# В актив ГАЗПРОМ ао вложил 1458.0551020852417 и получил 1413.365756678455
# Банк 0.0
# Портфель на момент 2022-12-01 : ['ГАЗПРОМ ао']
# Накопленная доходность портфеля : 1413.365756678455
# Угаданных направлений: 43
# Неугаданных направлений: 43
# ___________________________
#
# В день 2023-01-01 ничего не покупалось
# Банк 1413.365756678455
# Портфель на момент 2023-01-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 44
# Неугаданных направлений: 43
# ___________________________
#
# В день 2023-02-01 ничего не покупалось
# Банк 1413.365756678455
# Портфель на момент 2023-02-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 46
# Неугаданных направлений: 45
# ___________________________
#
# В день 2023-03-01 ничего не покупалось
# Банк 1413.365756678455
# Портфель на момент 2023-03-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 46
# Неугаданных направлений: 45
# ___________________________
#
# В день 2023-04-01 ничего не покупалось
# Банк 1413.365756678455
# Портфель на момент 2023-04-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 46
# Неугаданных направлений: 47
# ___________________________
#
# В актив МКБ ао вложил 1413.365756678455 и получил 1241.6676853188003
# Банк 0.0
# Портфель на момент 2023-05-01 : ['МКБ ао']
# Накопленная доходность портфеля : 1241.6676853188003
# Угаданных направлений: 48
# Неугаданных направлений: 48
# ___________________________
#
# В день 2023-06-01 ничего не покупалось
# Банк 1241.6676853188003
# Портфель на момент 2023-06-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 49
# Неугаданных направлений: 49
# ___________________________
#
# В день 2023-07-01 ничего не покупалось
# Банк 1241.6676853188003
# Портфель на момент 2023-07-01 : []
# Накопленная доходность портфеля : 0
# Угаданных направлений: 49
# Неугаданных направлений: 52
# ___________________________

# %% [markdown]
# ### Динамика угаданных и неугаданных направлений

# %%
plt.rcParams["figure.figsize"] = 18, 5
plt.plot(pd.DataFrame(grow_hit_list).set_index(trading_days) ,color='blue')
plt.plot(pd.DataFrame(fall_hit_list).set_index(trading_days),color='red' )
plt.plot(pd.DataFrame(grow_miss_list).set_index(trading_days),color='green' )
plt.plot(pd.DataFrame(fall_miss_list).set_index(trading_days),color='black' )
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %% [markdown]
# ### Динамика коэффициента отношения hit/miss

# %%
plt.rcParams["figure.figsize"] = 18, 5

plt.plot(pd.DataFrame(fall_miss_ratio).set_index(trading_days),color='red'  )
plt.title('Отношение hit/miss')
# Out:
# Text(0.5, 1.0, 'Отношение hit/miss')

# %% [markdown]
# ### Динамика общего капитала(деньги в банке+портфеле)

# %%
plt.rcParams["figure.figsize"] = 18, 5

plt.plot(pd.DataFrame(capital).set_index(trading_days),color='green'  )
plt.title('Общий капитал')
# Out:
# Text(0.5, 1.0, 'Общий капитал')

# %% [markdown]
# ### функция торгового алгоритма

# %%
def trade_func(total_df , upper_bound , lower_bound):
    trading_days = total_df.index.unique() #Набор торговых дней с предсказаниями и фактами
    bank = 1000 #Сумма денег на моём счету , которые я вкладываю . Это не накопленная стоимость портфеля 
    portfolio = {} #Ключ - актив , значение - накопленный по нему доход
    grow_hit = 0 #Подсчёт попаданий на росте
    fall_hit = 0 #Подсчёт попаданий на падении
    grow_miss = 0 #Подсчёт промахов и на росте и на падении
    fall_miss = 0
    grow_hit_list = [] 
    fall_hit_list = [] 
    grow_miss_list = [] 
    fall_miss_list = []
    fall_miss_ratio = []
    capital = [] #Сумма денег в портфеле и банке которую в корце визуализирую
    coef = 0
    
    
    for day in trading_days:
        #Устанавливаем активы , которые вносим в списки потенциального роста и потенциального падения
        good_assets = total_df.loc[(total_df.prob_of_growth > upper_bound) & (total_df.index == day)].ticker.values
        bad_assets = total_df.loc[(total_df.prob_of_growth < lower_bound) & (total_df.index == day)].ticker.values
        
        #Продаём все активы перед началом торгового дня
        for asset in list(portfolio):
            bank+=portfolio[asset]
            del portfolio[asset]
    
        #Продаём активы из зоны падения и возвращаем полученные деньги в банк
        for asset in bad_assets: 
            if asset in list(portfolio):
                bank+=portfolio[asset]
                del portfolio[asset]
            #Проверяем угадали ли направление
            if 1 > (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):#1+реальная доходность
                fall_hit+=1
            elif 1 < (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
                fall_miss+=1
        
        
        #Определяем разер вложений.
        if len(good_assets) != 0:
            invest_ammout = bank/len(good_assets)#вкладываем весь банк равномерно
        else :
            invest_ammout = 0
        
        #Покупаем активы из зоны роста
        for asset in good_assets: 
            if asset not in list(portfolio): #Если его нет в портфеле ,то добавляем его
                portfolio[asset] = (invest_ammout)*(1 + total_df.loc[total_df.ticker == asset].loc[day][0])#(1+real_ret)
                bank -= invest_ammout
                #Проверка угадано ли направление доходности
                if 1 < (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
                    grow_hit+=1
                elif 1 > (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
                    grow_miss+=1
            #elif asset in list(portfolio): #Если такой актив уже есть
                #portfolio[asset] += invest_ammout #Прибавляем к уже имеющимся вложениям а затем умножем на 1+real return
                #portfolio[asset] = portfolio[asset] * (1 + total_df.loc[total_df.ticker == asset].loc[day][0])
                #bank -= invest_ammout
                #Проверка угадано ли направление доходности
                #if 1 < (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
                    #grow_hit+=1
                #elif 1 > (1 + total_df.loc[total_df.ticker == asset].loc[day][0]):
                    #miss+=1 
            
            #print(f"В актив { asset } вложил { invest_ammout } и получил {(invest_ammout)*(1 + total_df.loc[total_df.ticker == asset].loc[day][0])}")    
            
    #Пополняю списки попаданий и промахов в конце каждого дня
        grow_hit_list.append(grow_hit)
        fall_hit_list.append(fall_hit)
        grow_miss_list.append(grow_miss)
        fall_miss_list.append(fall_miss)
        if grow_miss+fall_miss != 0:
            fall_miss_ratio.append( (grow_hit+fall_hit)/(grow_miss+fall_miss) )
        capital.append( bank+(sum(portfolio[x] for x in portfolio)) )
        coef = np.mean(capital)/np.std(capital)
    #____________________ИНФОРМАЦИОННОЕ ОКНО_____________________   
        #if len(list(portfolio)) == 0 :
            #print(f"В день {day} ничего не покупалось")
        #print(f"Банк {bank}")
        #print(f"Портфель на момент {day} : {list(portfolio)}")
        #print(f"Накопленная доходность портфеля : {sum(portfolio[x] for x in portfolio)}")
        #print(f"Угаданных направлений: {grow_hit+fall_hit}")
        #print(f"Неугаданных направлений: {fall_miss+grow_miss}")
        #print('___________________________\n')
    return [capital , coef]

# %% [markdown]
# # Оптимизация модели по параметру E/Sigma

# %%
lower_bounds = np.arange(0.1, 0.4, 0.1)
upper_bounds = np.arange(0.6 , 0.9 , 0.1)
params = product(upper_bounds, lower_bounds)

# %%
dct = {}
for param in params : 
    res = trade_func(total_df , round(param[0],2) , round(param[1],2))
    dct[round(param[0],2),round(param[1],2)] = [res[0][-1] , res[1]]

# %%
dct
# Out:
# {(0.6, 0.1): [994.4698331750142, 4.172655694126579],
#  (0.6, 0.2): [994.4698331750142, 4.172655694126579],
#  (0.6, 0.3): [994.4698331750142, 4.172655694126579],
#  (0.6, 0.4): [994.4698331750142, 4.172655694126579],
#  (0.7, 0.1): [811.7694585579932, 3.1173573302746846],
#  (0.7, 0.2): [811.7694585579932, 3.1173573302746846],
#  (0.7, 0.3): [811.7694585579932, 3.1173573302746846],
#  (0.7, 0.4): [811.7694585579932, 3.1173573302746846],
#  (0.8, 0.1): [1241.6676853188003, 6.671975857956967],
#  (0.8, 0.2): [1241.6676853188003, 6.671975857956967],
#  (0.8, 0.3): [1241.6676853188003, 6.671975857956967],
#  (0.8, 0.4): [1241.6676853188003, 6.671975857956967],
#  (0.9, 0.1): [911.3861239211845, 21.824712631527508],
#  (0.9, 0.2): [911.3861239211845, 21.824712631527508],
#  (0.9, 0.3): [911.3861239211845, 21.824712631527508],
#  (0.9, 0.4): [911.3861239211845, 21.824712631527508]}
